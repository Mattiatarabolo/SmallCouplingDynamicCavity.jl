# %%
include("src/SCDC.jl")
using Revise, SparseArrays
using Graphs, LaTeXStrings, Printf
using GraphRecipes,NetworkLayout
using Plots
using Compose
using Distributions

# %% [markdown]
# # Tree

# %%
k = 3 # number of graph vertices
tmax = 3

V,E = bethe_lattice(k,tmax,true) ; NV= length(V)
G = SimpleGraph(Edge.([(x[1],x[2]) for x in E]))

# in this cell I create some random links to introduce some loops on the graph G which is a Tree
for st = 1:0#NV/3
    i = rand(1:NV)
    i == NV && continue
    j = rand(i+1:NV)
    add_edge!(G,i,j)
    add_edge!(G,j,i) 
end

display(graphplot(G,names=1:NV,edgecolor=:black,curves=false,nodeshape=:circle, markersize =.2))
display(sparse(G))
# Out:
# 22×22 SparseMatrixCSC{Int64, Int64} with 42 stored entries:
# ⡎⠉⠒⠤⣀⠀⠀⠀⠀⠀⠀
# ⠘⡄⠀⠀⠀⠉⠒⠤⣀⠀⠀
# ⠀⠘⡄⠀⠀⠀⠀⠀⠀⠉⠒
# ⠀⠀⠘⡄⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠘⡄⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠘⠀⠀⠀⠀⠀⠀

# %% [markdown]
# ## - SIRS:
#
# ### System parameter definition and simulation

# %%
# define the constants
const T::Int = 20 # total time
const fₚ::Float64 = 0.0 # false-positive rate
const fₙ::Float64 = 0.0 # false-negative rate
const γ::Float64 = 1/NV # Patient zero probability
const λ₀::Float64 = 0.2 # Infection rate

# define the observation probability
function obsprob(Ob::Float64, x::Float64)
    if Ob == -1.0
        return 1.0
    else
        return Float64(Ob == x)
    end
end

# randomly generate the infection probability Matrix
#λ = zeros(NV, NV, T+1)
#for e in edges(G)
#    λ[src(e), dst(e), :] = rand(T+1)
#    λ[dst(e), src(e), :] = rand(T+1)
#end

# constant infection probability
λ = zeros(NV, NV, T+1)
for e in edges(G)
    λ[src(e), dst(e), :] = ones(T+1) * λ₀
    λ[dst(e), src(e), :] = ones(T+1) * λ₀
end

# epidemic simulation
config = sim_epidemics(G, log.(1 .- λ), T, γ, :SI, patient_zero = true)
#display(perm_sort)
#display(config)
#display(config[perm_sort,:])

isource = findall(x->x==1.0, config[:,1])
println("sources: $(isource)")

# infected individuals over time
nrI = dropdims(sum(map(x->Float64(x==1.0),config), dims = 1), dims = 1)
nrS = dropdims(sum(map(x->Float64(x==0.0),config), dims = 1), dims = 1)
#nrR = dropdims(sum(map(x->Float64(x==2.0),config), dims = 1), dims = 1)
display(plot([nrS nrI], xlabel = "Days", ylabel = "", label = ["S" "I"]))

# display epidemy
display(heatmap(config,title="Infected",xlabel="time",ylabel="population"))
# Out:
# sources: [14]

# %% [markdown]
# ### Generation of observations

# %%
using JLD

#observed = [1]

data = load("rho_supershort_tree.jld")
G = data["G"]
config = data["config"]
T = data["T"]
λ₀ = data["lambda"]
observed = data["observed"];
#save("rho_supershort_tree.jld", "G", G, "config", config, "T", T, "lambda", λ₀, "observed", observed)

# %% [markdown]
# ### Inference SCDC-- autoinfection, $\mu$ cutoff

# %%
# computational constants
const epsconv::Float64 = 5e-15 # convergence threshold
const maxiter::Int = 5e2 # max number of iterations
const damp::Float64 = 0.0 # damping factor
const μ_cutoff::Float64 = -Inf
const ε_autoinf::Float64 = 0.0

# callback function
function report(nodes,iter,ε) 
    println("i = ", iter,  " ε = ", ε)
end
# Out:
# report (generic function with 1 method)

# %% [markdown]
# ## $\rho$ visualization

# %%
mark = [:circle, :square, :star, :utriangle, :diamond, :cross]
g = cgrad(:inferno)
col = [g[1], g[100], g[160], g[190], g[210], g[240]]

path = [1, 4, 9, 19]


######## Susceptible ##############
t_obs = 8 #ceil(Int,T/2)+

# generate observations
obsmat = ones(NV, T+1) * (-1.0)
obslist = []
for iₗ in observed
    obsmat[iₗ, t_obs+1] = config[iₗ, t_obs+1]
    push!(obslist, (iₗ, ceil(Int,t_obs)))
end
println(obslist)

nodes = run_SCDC(G, λ, obsmat, obsprob, γ, T, maxiter, epsconv, damp, :SI, callback = report, μ_cutoff = μ_cutoff, ε_autoinf = ε_autoinf);

index = 1
i = path[1]
j = path[2]
p1 = plot(0:T, nodes[j].ρs[nodes[j].∂_idx[i]].fwm[2,:], label=L"%$i \rightarrow %$j", color=col[index], width=2, markers=mark[index])
for i in path[2:end-1]
    index += 1
    j = path[index+1]
    plot!(p1, 0:T, nodes[j].ρs[nodes[j].∂_idx[i]].fwm[2,:], label=L"%$i \rightarrow %$j", color=col[index], width=2, markers=mark[index])
end
plot!(p1, guidefontsize=14, ylabel=L"\rho_{t\leftarrow}^{i\setminus j}(x_i^t=I)", xtickfontsize=10, ytickfontsize=10, yformatter = :plain, xlabel=L"t")



######### Infected ###################
t_obs = 12 #ceil(Int,T/2)+

# generate observations
obsmat = ones(NV, T+1) * (-1.0)
obslist = []
for iₗ in observed
    obsmat[iₗ, t_obs+1] = config[iₗ, t_obs+1]
    push!(obslist, (iₗ, ceil(Int,t_obs)))
end
println(obslist)

nodes = run_SCDC(G, λ, obsmat, obsprob, γ, T, maxiter, epsconv, damp, :SI, callback = report, μ_cutoff = μ_cutoff, ε_autoinf = ε_autoinf);

index = 1
i = path[1]
j = path[2]
p2 = plot(0:T, nodes[j].ρs[nodes[j].∂_idx[i]].fwm[2,:], label=L"%$i \rightarrow %$j", color=col[index], width=2, markers=mark[index])
for i in path[2:end-1]
    index += 1
    j = path[index+1]
    plot!(p2, 0:T, nodes[j].ρs[nodes[j].∂_idx[i]].fwm[2,:], label=L"%$i \rightarrow %$j", color=col[index], width=2, markers=mark[index])
end
plot!(p2, guidefontsize=14, xtickfontsize=10, ytickfontsize=10, yformatter = :plain, xlabel=L"t")


########### final plot #####################
cols = [:blues for _=1:NV]
cols[observed] .= :red
pgraph = graphplot(G, markercolor=cols, names=1:NV, markersize = 0.20, edgecolor=:black, curves=false, nodeshape=:circle, label = "", size=(400,400))

ptot = plot(pgraph, p1, p2, layout = (1, 3), legend = true, legendfontsize=10, size = (900, 250), margin=0Plots.mm, bottommargin=7Plots.mm, axis_buffer=0.001)
display(ptot)

#savefig(ptot, "rhos_backward_900x250.pdf")
# Out:
# Any[(1, 8)]
# i = 1 ε = 0.978972460784287
# i = 2 ε = 0.5535689781690896
# i = 3 ε = 0.2673093317229257
# i = 4 ε = 0.006804072102218672
# i = 5 ε = 0.0
# Converged after 5 iterations
# Any[(1, 12)]
# i = 1 ε = 7.634787143138911
# i = 2 ε = 5.768609605540932
# i = 3 ε = 1.1898023399379345
# i = 4 ε = 0.023722197042346682
# i = 5 ε = 0.0
# Converged after 5 iterations

# %% [markdown]
# ## $\mu$ visualization

# %%
k = 3 # number of graph vertices
tmax = 5

V,E = bethe_lattice(k,tmax,true) ; NV= length(V)
G = SimpleGraph(Edge.([(x[1],x[2]) for x in E]))

# in this cell I create some random links to introduce some loops on the graph G which is a Tree
for st = 1:NV*.1
    i = rand(1:NV)
    i == NV && continue
    j = rand(i+1:NV)
    add_edge!(G,i,j)
    add_edge!(G,j,i) 
end

# %%
display(graphplot(G, names=1:NV, edgecolor=:black,curves=false,nodeshape=:circle, markersize =.15, size=(500,500)))#, layout_kw=Dict(:seed=>1998)))
display(sparse(G))
# Out:
# 94×94 SparseMatrixCSC{Int64, Int64} with 204 stored entries:
# ⣎⠙⠢⢄⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠈⢆⠀⠀⠀⠉⠒⢄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠘⡄⠀⠀⠀⠀⠀⠈⠉⠓⠤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠘⢄⠀⠀⠀⠀⠀⠀⠀⠀⠈⠑⠢⠤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠲⢄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠙⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠒⠤⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠘⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠑⠒⠦⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠀⠀⠀⠀⠀⠙⠢⢄⣀⠀⠀⡀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠘⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠒⢤⡀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠘⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠑⠒⠤
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡄⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠠⠀⠀⠀⠀⠀⠘⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠘⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢆⠀⠀⠠⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⡄⠀⠀⠄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠠⠂

# %% [markdown]
# ## - SIRS:
#
# ### System parameter definition and simulation

# %%
# define the constants
const T::Int = 100 # total time
const fₚ::Float64 = 0.0 # false-positive rate
const fₙ::Float64 = 0.0 # false-negative rate
const γ::Float64 = 1/NV # Patient zero probability
const λ₀::Float64 = 0.1 # Infection rate

# define the observation probability
function obsprob(Ob::Float64, x::Float64)
    if Ob == -1.0
        return 1.0
    else
        return Float64(Ob == x)
    end
end

# randomly generate the infection probability Matrix
#λ = zeros(NV, NV, T+1)
#for e in edges(G)
#    λ[src(e), dst(e), :] = rand(T+1)
#    λ[dst(e), src(e), :] = rand(T+1)
#end

# constant infection probability
λ = zeros(NV, NV, T+1)
for e in edges(G)
    λ[src(e), dst(e), :] = ones(T+1) * λ₀
    λ[dst(e), src(e), :] = ones(T+1) * λ₀
end

# epidemic simulation
config = sim_epidemics(G, log.(1 .- λ), T, γ, :SI, patient_zero = true)
#display(perm_sort)
#display(config)
#display(config[perm_sort,:])

isource = findall(x->x==1.0, config[:,1])
println("sources: $(isource)")

# infected individuals over time
nrI = dropdims(sum(map(x->Float64(x==1.0),config), dims = 1), dims = 1)
nrS = dropdims(sum(map(x->Float64(x==0.0),config), dims = 1), dims = 1)
#nrR = dropdims(sum(map(x->Float64(x==2.0),config), dims = 1), dims = 1)
display(plot([nrS nrI], xlabel = "Days", ylabel = "", label = ["S" "I"]))

# display epidemy
display(heatmap(config,title="Infected",xlabel="time",ylabel="population"))
# Out:
# sources: [88]

# %% [markdown]
# ### Generation of observations

# %%
t_obs = 50
# Out:
# 50

# %% [markdown]
# ### Inference SCDC-- autoinfection, $\mu$ cutoff

# %%
# computational constants
const epsconv::Float64 = 5e-15 # convergence threshold
const maxiter::Int = 5e2 # max number of iterations
const damp::Float64 = 0.0 # damping factor
const μ_cutoff::Float64 = -Inf
const ε_autoinf::Float64 = 0.0

# callback function
function report(nodes,iter,ε) 
    println("i = ", iter,  " ε = ", ε)
end
# Out:
# report (generic function with 1 method)

# %%
function norm_μ(i::Int,j::Int,nodes::Vector)
    iindex = nodes[j].∂_idx[i]  #calculate the norm of μ at node i for the j_th coNVection
    sqrt(sum((nodes[j].cavities[iindex].μ) .^ 2))
end
# Out:
# norm_μ (generic function with 1 method)

# %%
using Random

spess = [5, 5, 10, 10, 10, 10, 60]

######## 1 obs ##############
observed = [1]

# generate observations
obsmat = ones(NV, T+1) * (-1.0)
obslist = []
for iₗ in observed
    obsmat[iₗ, t_obs+1] = config[iₗ, t_obs+1]
    push!(obslist, (iₗ, ceil(Int,t_obs)))
end
println(obslist)

nodes = run_SCDC(G, λ, obsmat, obsprob, γ, T, maxiter, epsconv, damp, :SI, callback = report, μ_cutoff = μ_cutoff, ε_autoinf = ε_autoinf)

μ = zeros(NV,NV)
for e in edges(G)
    i = src(e)
    j = dst(e)
    μ[i,j] += norm_μ(i,j,nodes)
    μ[j,i] += norm_μ(j,i,nodes)
end
μ .+= μ'

cols = [:blues for _=1:NV]
cols[observed] .= :red
μs = spess[length(observed)] * sparse((μ) ./ maximum(μ)) #qui ci metto lo spessore
Random.seed!(1998)
p1 = graphplot(G; edgewidth=(s,d,w) -> μs[s,d], markercolor=cols, markersize = 0.18, edgecolor=:black, curves=false, nodeshape=:circle, axisbuffer=0.05)



######## 2 obs ##############
observed = [1, 8]

# generate observations
obsmat = ones(NV, T+1) * (-1.0)
obslist = []
for iₗ in observed
    obsmat[iₗ, t_obs+1] = config[iₗ, t_obs+1]
    push!(obslist, (iₗ, ceil(Int,t_obs)))
end
println(obslist)

nodes = run_SCDC(G, λ, obsmat, obsprob, γ, T, maxiter, epsconv, damp, :SI, callback = report, μ_cutoff = μ_cutoff, ε_autoinf = ε_autoinf)

μ = zeros(NV,NV)
for e in edges(G)
    i = src(e)
    j = dst(e)
    μ[i,j] += norm_μ(i,j,nodes)
    μ[j,i] += norm_μ(j,i,nodes)
end
μ .+= μ'


cols = [:blues for _=1:NV]
cols[observed] .= :red
μs = spess[length(observed)] * sparse((μ) ./ maximum(μ)) #qui ci metto lo spessore
Random.seed!(1998)
p2 = graphplot(G; edgewidth=(s,d,w) -> μs[s,d], markercolor=cols, markersize = 0.18, edgecolor=:black, curves=false, nodeshape=:circle, axisbuffer=0.05)

########### final plot #####################
ptot = plot(p1, p2, layout = (1, 2), size = (900, 350), margin=0Plots.mm)
display(ptot)

savefig(ptot, "mus_900x350.pdf")
# Out:
# Any[(1, 50)]
# i = 1 ε = 78.014246015351
# i = 2 ε = 76.17693635544018
# i = 3 ε = 79.6005578203145
# i = 4 ε = 56.482475759261284
# i = 5 ε = 5.121008744629018
# i = 6 ε = 0.590996273400237
# i = 7 ε = 0.17573765639076078
# i = 8 ε = 0.07924759430304584
# i = 9 ε = 0.03355955318559656
# i = 10 ε = 0.002848131907775109
# i = 11 ε = 0.0012548038255098086
# i = 12 ε = 0.0004836872740194755
# i = 13 ε = 9.311379635379424e-5
# i = 14 ε = 4.589764942852792e-5
# i = 15 ε = 1.5570149879073902e-5
# i = 16 ε = 2.3534677533465498e-6
# i = 17 ε = 1.0352705429820391e-6
# i = 18 ε = 3.283716653052632e-7
# i = 19 ε = 9.325597793985452e-8
# i = 20 ε = 4.9655382916569124e-8
# i = 21 ε = 1.3107480767438062e-8
# i = 22 ε = 2.7524541534873492e-9
# i = 23 ε = 1.0699433309821482e-9
# i = 24 ε = 3.044482322495101e-10
# i = 25 ε = 1.1704337499196527e-10
# i = 26 ε = 4.8487769355176624e-11
# i = 27 ε = 1.3077205984757256e-11
# i = 28 ε = 2.8341773372630996e-12
# i = 29 ε = 1.0694604923866535e-12
# i = 30 ε = 3.088978725585001e-13
# i = 31 ε = 1.312283615106935e-13
# i = 32 ε = 4.807265696626928e-14
# i = 33 ε = 1.3433698597964394e-14
# i = 34 ε = 2.9004576518332215e-15
# Converged after 34 iterations
# Any[(1, 50), (8, 50)]
# i = 1 ε = 78.04253889725545
# i = 2 ε = 76.17693635544018
# i = 3 ε = 80.20018331331866
# i = 4 ε = 58.87312199096429
# i = 5 ε = 38.909820694264106
# i = 6 ε = 0.6179547660643847
# i = 7 ε = 0.31864110803066215
# i = 8 ε = 0.1936203550982854
# i = 9 ε = 0.03372928583116097
# i = 10 ε = 0.02366221180640407
# i = 11 ε = 0.00880771099893217
# i = 12 ε = 0.0025638193234011064
# i = 13 ε = 0.0011997025910588377
# i = 14 ε = 0.0005242956156751716
# i = 15 ε = 0.000350179549382601
# i = 16 ε = 0.0001825722448807604
# i = 17 ε = 5.2624637908546545e-5
# i = 18 ε = 1.832552664515763e-5
# i = 19 ε = 8.371135263529617e-6
# i = 20 ε = 5.9281874951883085e-6
# i = 21 ε = 3.0837903906844044e-6
# i = 22 ε = 1.0348896440914856e-6
# i = 23 ε = 3.148191144441981e-7
# i = 24 ε = 1.4558780048190556e-7
# i = 25 ε = 1.0907141453908586e-7
# i = 26 ε = 5.734411480384782e-8
# i = 27 ε = 2.0616214568836e-8
# i = 28 ε = 5.80409409423055e-9
# i = 29 ε = 2.6995721214007062e-9
# i = 30 ε = 1.8662235645727776e-9
# i = 31 ε = 1.0370724140562615e-9
# i = 32 ε = 3.8899782006662775e-10
# i = 33 ε = 1.0537503161711648e-10
# i = 34 ε = 4.958167210133979e-11
# i = 35 ε = 3.238249945969329e-11
# i = 36 ε = 1.9014609331513554e-11
# i = 37 ε = 7.457631734375525e-12
# i = 38 ε = 1.9258847988590233e-12
# i = 39 ε = 9.199307982044047e-13
# i = 40 ε = 5.59094437413421e-13
# i = 41 ε = 3.4199032494797166e-13
# i = 42 ε = 1.4017953464673383e-13
# i = 43 ε = 3.957945082788683e-14
# i = 44 ε = 1.6986412276764895e-14
# i = 45 ε = 1.1421419365831298e-14
# i = 46 ε = 6.147859998861804e-15
# i = 47 ε = 5.176414852314792e-15
# i = 48 ε = 1.8665624601510444e-15
# Converged after 48 iterations
# "/home/tara/Desktop/SCDC/mus_900x350.pdf"

# %% [markdown]
# Dove ci sono più cicli/path i mu sono maggiori.
#
# Due figure, una ossrvazione infetto, l'altra osservazione suscettibile.
